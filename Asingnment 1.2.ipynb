# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
NBA=pd.read_csv("NBA_data.csv")

# %%
NBA
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
NBA.head(12)
# Out:
#                       Player Position  Age  Games  Minutes Played  \
# 0           Precious Achiuwa       PF   21     28           408.0
# 1               Jaylen Adams       PG   24      6            17.0
# 2               Steven Adams        C   27     27           760.0
# 3                Bam Adebayo        C   23     26           873.0
# 4          LaMarcus Aldridge        C   35     18           480.0
# 5          Ty-Shon Alexander       SG   22      3             8.0
# 6   Nickeil Alexander-Walker       SG   22     23           441.0
# 7              Grayson Allen       SG   25     19           454.0
# 8              Jarrett Allen        C   22     28           734.0
# 9              Jarrett Allen        C   22     12           320.0
# 10             Jarrett Allen        C   22     16           414.0
# 11           Al-Farouq Aminu       PF   30      2            16.0
#
#     True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# ...

# %%
NBA=NBA.dropna()
NBA
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# 5    Ty-Shon Alexander       SG   22      3             8.0             0.000
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
NBA.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  489.000000  489.000000      489.000000        489.000000
# mean    25.638037   18.427403      416.032720          0.538603
# std      4.065784    8.324573      298.056483          0.130750
# min     19.000000    1.000000        2.000000          0.000000
# 25%     22.000000   12.000000      124.000000          0.500000
# 50%     25.000000   20.000000      417.000000          0.556000
# 75%     28.000000   26.000000      665.000000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               489.000000               489.000000
# mean                  0.407644                 0.273131
# std                   0.234085                 0.271252
# min                   0.000000                 0.000000
# 25%                   0.255000                 0.141000
# ...

# %%
NBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    489 non-null    object
#  1   Position                  489 non-null    object
#  2   Age                       489 non-null    int64
#  3   Games                     489 non-null    int64
#  4   Minutes Played            489 non-null    float64
#  5   True Shooting(%)          489 non-null    float64
#  6   Threepoint Attempt rate   489 non-null    float64
#  7   Free throw attempt rate   489 non-null    float64
#  8   Player Efficiency Rating  489 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 38.2+ KB

# %%
print(NBA.loc[0:496,['Position','Age']])
# Out:
#     Position  Age
# 0         PF   21
# 1         PG   24
# 3          C   23
# 4          C   35
# 5         SG   22
# ..       ...  ...
# 492       SG   28
# 493       PF   32
# 494       PG   22
# 495        C   28
# 496        C   23
#
# [489 rows x 2 columns]

# %%
print(NBA["Position"])
# Out:
# 0      PF
# 1      PG
# 3       C
# 4       C
# 5      SG
#        ..
# 492    SG
# 493    PF
# 494    PG
# 495     C
# 496     C
# Name: Position, Length: 489, dtype: object

# %%
NBA["Player"]
# Out:
# 0       Precious Achiuwa
# 1           Jaylen Adams
# 3            Bam Adebayo
# 4      LaMarcus Aldridge
# 5      Ty-Shon Alexander
#              ...
# 492         Delon Wright
# 493       Thaddeus Young
# 494           Trae Young
# 495          Cody Zeller
# 496          Ivica Zubac
# Name: Player, Length: 489, dtype: object

# %%
NBAPF=NBA.groupby(["Position"]).get_group(("PF"))

# %%
NBAPF
# Out:
#                     Player Position  Age  Games  Minutes Played  \
# 0         Precious Achiuwa       PF   21     28           408.0
# 11         Al-Farouq Aminu       PF   30      2            16.0
# 12           Kyle Anderson       PF   27     24           675.0
# 13   Giannis Antetokounmpo       PF   26     27           906.0
# 14    Kostas Antetokounmpo       PF   23      1             8.0
# ..                     ...      ...  ...    ...             ...
# 481       Kenrich Williams       PF   26     28           512.0
# 483       Patrick Williams       PF   19     26           720.0
# 485        Zion Williamson       PF   20     27           880.0
# 486            D.J. Wilson       PF   24     10            94.0
# 493         Thaddeus Young       PF   32     23           592.0
#
#      True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# 0               0.599                    0.000                    0.541
# ...

# %%
print(NBAPF.loc[0:496,['Position','Age']])
# Out:
#     Position  Age
# 0         PF   21
# 11        PF   30
# 12        PF   27
# 13        PF   26
# 14        PF   23
# ..       ...  ...
# 481       PF   26
# 483       PF   19
# 485       PF   20
# 486       PF   24
# 493       PF   32
#
# [102 rows x 2 columns]

# %%
sns.relplot(x='Position',y='Age',data=NBA,hue='Position')

# %%
NBA
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# 5    Ty-Shon Alexander       SG   22      3             8.0             0.000
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
NBA.plot.bar("Position","Age")
# Out:
# <AxesSubplot:xlabel='Position'>

# %%
sns.catplot(x='Position',y='Player Efficiency Rating',data=NBA,kind="box")

# %%
NBAdata.head(20)
# Out:
#                       Player Position  Age  Games  Minutes Played  \
# 0           Precious Achiuwa       PF   21     28           408.0
# 1               Jaylen Adams       PG   24      6            17.0
# 2               Steven Adams        C   27     27           760.0
# 3                Bam Adebayo        C   23     26           873.0
# 4          LaMarcus Aldridge        C   35     18           480.0
# 5          Ty-Shon Alexander       SG   22      3             8.0
# 6   Nickeil Alexander-Walker       SG   22     23           441.0
# 7              Grayson Allen       SG   25     19           454.0
# 8              Jarrett Allen        C   22     28           734.0
# 9              Jarrett Allen        C   22     12           320.0
# 10             Jarrett Allen        C   22     16           414.0
# 11           Al-Farouq Aminu       PF   30      2            16.0
# 12             Kyle Anderson       PF   27     24           675.0
# ...
